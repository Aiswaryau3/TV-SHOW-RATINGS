# %% [markdown]
# ### **Summary Recommendation**
#
# * The dataset contains **1511 TV shows** with multiple attributes like **Type, Language, Average Runtime, Ratings, and Genres**.
# * Data cleaning involved removing empty columns, handling missing values, and dropping duplicates to ensure accurate analysis.
# * Exploratory data analysis (EDA) was performed to uncover patterns in show characteristics and viewer preferences.
#
# ---
#
# ### **Key Insights**
#
# 1. **Data Structure & Quality**
#
#    * 12 columns and 1511 rows.
#    * Minimal missing values after cleaning; duplicates removed.
#    * Mix of numeric (runtime, rating) and categorical (language, type) columns.
#
# 2. **Show Runtime**
#
#    * Most shows have runtimes between **20–60 minutes**.
#    * Very few shows exceed 120 minutes.
#
# 3. **Language & Type**
#
#    * Certain languages dominate (e.g., English shows are more common).
#    * Types of shows (Drama, Reality, Comedy, etc.) are unevenly distributed.
#
# 4. **Ratings & Performance**
#
#    * Higher ratings are concentrated in specific **genres** and **languages**.
#    * Shows with moderate runtime tend to have slightly higher viewer ratings.
#
# 5. **Trends**
#
#    * Popular genres and languages attract the most viewers.
#    * Extreme outliers in runtime or rating exist but are rare.
#
# ---
#
# ### **Recommendations**
#
# 1. **Content Strategy**
#
#    * Focus on producing shows in **languages with higher representation**, as they have proven audience engagement.
#    * Prioritize popular **genres** for new productions or acquisitions.
#
# 2. **Runtime Optimization**
#
#    * Target the **20–60 minute runtime window**, which is preferred by most viewers.
#    * Avoid excessively long episodes unless for niche or premium content.
#
# 3. **Quality over Quantity**
#
#    * Invest in **higher-rated types and genres**, as they drive viewer satisfaction and retention.
#    * Consider creating spin-offs or sequels of high-performing shows.
#
# 4. **Diversity**
#
#    * Explore underrepresented languages or niche genres to **capture untapped audiences**.
#    * Test new formats or hybrid genres for innovation.
#
# 5. **Recommendation Systems**
#
#    * Use ratings and genre-language trends to build a **personalized TV show recommendation engine** for users.
#
# ---
#
# ### **Final Conclusion**
#
# * The dataset offers **valuable insights into TV show characteristics and viewer preferences**.
# * With targeted content strategy and optimization of runtime, language, and genres, platforms can **maximize engagement, retention, and viewership**.
# * The dataset is well-prepared for **predictive analytics**, audience segmentation, and recommendation systems.
